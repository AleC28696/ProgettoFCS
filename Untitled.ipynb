# %% [markdown]
# # 1.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
loans_lenders = pd.read_csv('loans_lenders.csv')
loans_lenders.head()
# Out:
#    loan_id                                            lenders
# 0   483693  muc888, sam4326, camaran3922, lachheb1865, reb...
# 1   483738  muc888, nora3555, williammanashi, barbara5610,...
# 2   485000  muc888, terrystl, richardandsusan8352, sherri4...
# 3   486087  muc888, james5068, rudi5955, daniel9859, don92...
# 4   534428  muc888, niki3008, teresa9174, mike4896, david7...

# %%
loans_lenders_normalized = loans_lenders.assign(lenders=loans_lenders['lenders'].str.split(', ')).explode('lenders')
loans_lenders_normalized
# Out:
#          loan_id            lenders
# 0         483693             muc888
# 0         483693            sam4326
# 0         483693        camaran3922
# 0         483693        lachheb1865
# 0         483693        rebecca3499
# ...          ...                ...
# 1387430  1206425  trogdorfamily7622
# 1387430  1206425          danny6470
# 1387430  1206425            don6118
# 1387431  1206486           alan5175
# 1387431  1206486        amy38101311
#
# [28293931 rows x 2 columns]

# %% [markdown]
# # 2.

# %%
loans = pd.read_csv('loans.csv')
loans
# Out:
#          loan_id           loan_name original_language  \
# 0         657307                Aivy           English
# 1         657259      Idalia Marizza           Spanish
# 2         658010               Aasia           English
# 3         659347             Gulmira           Russian
# 4         656933             Ricky\t           English
# ...          ...                 ...               ...
# 1419602   988180                 NaN               NaN
# 1419603   988213             Perlita           English
# 1419604   989109  Okyeso Nyame Group           English
# 1419605   989143            Exequila           English
# 1419606   989240               Lydia            French
#
#                                                description  \
# 0        Aivy, 21 years of age, is single and lives in ...
# 1        Doña Idalia, esta casada, tiene 57 años de eda...
# 2        Aasia is a 45-year-old married lady and she ha...
# 3        Гулмире 36 лет, замужем, вместе с супругом вос...
# ...

# %%
loans[['planned_expiration_time', 'disburse_time']]
# Out:
#                planned_expiration_time                  disburse_time
# 0        2014-02-14 03:30:06.000 +0000  2013-12-22 08:00:00.000 +0000
# 1        2014-03-26 22:25:07.000 +0000  2013-12-20 08:00:00.000 +0000
# 2        2014-02-15 21:10:05.000 +0000  2014-01-09 08:00:00.000 +0000
# 3        2014-02-21 03:10:02.000 +0000  2014-01-17 08:00:00.000 +0000
# 4        2014-02-13 06:10:02.000 +0000  2013-12-17 08:00:00.000 +0000
# ...                                ...                            ...
# 1419602  2016-01-02 01:00:03.000 +0000  2015-11-23 08:00:00.000 +0000
# 1419603  2016-01-02 16:40:07.000 +0000  2015-11-24 08:00:00.000 +0000
# 1419604  2016-01-03 22:20:04.000 +0000  2015-11-13 08:00:00.000 +0000
# 1419605  2016-01-05 08:50:02.000 +0000  2015-11-03 08:00:00.000 +0000
# 1419606  2016-01-03 20:50:06.000 +0000  2015-11-03 08:00:00.000 +0000
#
# [1419607 rows x 2 columns]

# %%
loans['planned_expiration_datetime'] =  pd.to_datetime(loans['planned_expiration_time'], format='%Y-%m-%d %H:%M:%S.%f %z')

# %%
loans['disburse_datetime'] =  pd.to_datetime(loans['disburse_time'], format='%Y-%m-%d %H:%M:%S.%f %z')

# %%
loans['timedelta'] = loans['planned_expiration_datetime'] - loans['disburse_datetime']

# %%
loans['duration'] = loans['timedelta'].dt.days

# %% [markdown]
# # 3.

# %%
loans_lenders_grouped = loans_lenders_normalized.groupby('lenders', as_index=False).count()
loans_lenders_grouped.columns = ['lenders', 'number_of_fundings']
loans_lenders_grouped = loans_lenders_grouped[loans_lenders_grouped['number_of_fundings'] >= 2]
loans_lenders_grouped
# Out:
#                 lenders  number_of_fundings
# 0                   000                  40
# 1                 00000                  39
# 2                  0002                  70
# 4        0101craign0101                  71
# 5               0132575                   4
# ...                 ...                 ...
# 1383792         zzinnia                  28
# 1383793      zzivnk7094                   4
# 1383794        zzmcfate                1730
# 1383796      zzrvmf8538                  15
# 1383797          zzzsai                   4
#
# [901811 rows x 2 columns]

# %% [markdown]
# # 4.

# %%
loans.columns
# Out:
# Index(['loan_id', 'loan_name', 'original_language', 'description',
#        'description_translated', 'funded_amount', 'loan_amount', 'status',
#        'activity_name', 'sector_name', 'loan_use', 'country_code',
#        'country_name', 'town_name', 'currency_policy',
#        'currency_exchange_coverage_rate', 'currency', 'partner_id',
#        'posted_time', 'planned_expiration_time', 'disburse_time',
#        'raised_time', 'lender_term', 'num_lenders_total',
#        'num_journal_entries', 'num_bulk_entries', 'tags', 'borrower_genders',
#        'borrower_pictured', 'repayment_interval', 'distribution_model',
#        'planned_expiration_datetime', 'disburse_datetime', 'timedelta',
#        'duration'],
#       dtype='object')

# %%
countries = loans[['country_name', 'loan_id']].groupby('country_name').count()
countries.columns = ['number_of_loans']
countries
# Out:
#                 number_of_loans
# country_name
# Afghanistan                2337
# Albania                    3075
# Armenia                   13952
# Azerbaijan                10172
# Belize                      218
# ...                         ...
# Vietnam                   21839
# Virgin Islands                2
# Yemen                      4206
# Zambia                     1277
# Zimbabwe                   5513
#
# [96 rows x 1 columns]
